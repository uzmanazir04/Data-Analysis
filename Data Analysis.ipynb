# %% [markdown]
# ## Salaries of Different Data Science Fields in the Data Science Domain

# %% [markdown]
# ###  **Importing Libraries**

# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### Importing Dataset

# %%
df=pd.read_csv('C:/Users/nazir/Downloads/archive/ds_salaries.csv')

# %% [markdown]
# ### Viewing dataset

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# ### Checking number of rows and column data

# %%
df.shape
# Out:
# (3755, 11)

# %% [markdown]
# ### Describing data

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %% [markdown]
# ### Checking Null values

# %%
df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ### Checking Duplicate rows

# %%
df.duplicated().sum()
# Out:
# 1171

# %% [markdown]
# ### Drop Duplicates

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# ### Checking Datatypes

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# ### Reseting index

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ### **Showing selective Columns**

# %%
df[['job_title','salary','company_location','company_size']]
# Out:
#                      job_title   salary company_location company_size
# 0     Principal Data Scientist    80000               ES            L
# 1                  ML Engineer    30000               US            S
# 2                  ML Engineer    25500               US            S
# 3               Data Scientist   175000               CA            M
# 4               Data Scientist   120000               CA            M
# ...                        ...      ...              ...          ...
# 2579            Data Scientist   412000               US            L
# 2580  Principal Data Scientist   151000               US            L
# 2581            Data Scientist   105000               US            S
# 2582     Business Data Analyst   100000               US            L
# 2583      Data Science Manager  7000000               IN            L
#
# [2584 rows x 4 columns]

# %% [markdown]
# ### Counting experience level

# %%
df["experience_level"].value_counts()
# Out:
# experience_level
# SE    1554
# MI     664
# EN     270
# EX      96
# Name: count, dtype: int64

# %% [markdown]
# ### Average Salary based on jobs

# %%
df["salary"].groupby(df["job_title"]).mean()
# Out:
# job_title
# 3D Computer Vision Researcher    120000.000000
# AI Developer                     137181.818182
# AI Programmer                     55000.000000
# AI Scientist                     275312.500000
# Analytics Engineer               149001.758242
#                                      ...
# Research Engineer                165510.727273
# Research Scientist               152924.600000
# Software Data Engineer            75000.000000
# Staff Data Analyst                15000.000000
# Staff Data Scientist             105000.000000
# Name: salary, Length: 93, dtype: float64

# %% [markdown]
# ### Job with highest salary

# %%
df[["job_title","salary"]].max()
# Out:
# job_title    Staff Data Scientist
# salary                   30400000
# dtype: object

# %% [markdown]
# ### Count on employees on the basis of Region

# %%
df["employee_residence"].value_counts()
# Out:
# employee_residence
# US    1893
# GB     150
# CA      81
# IN      70
# ES      47
#       ...
# BA       1
# AM       1
# CY       1
# KW       1
# MT       1
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# ### **Filtering companies thats size is large**

# %%
df[df["company_size"]=="L"]
# Out:
#       index  work_year experience_level employment_type  \
# 0         0       2023               SE              FT
# 5         5       2023               SE              FT
# 6         6       2023               SE              FT
# 13       13       2023               EN              FT
# 14       14       2023               EN              FT
# ...     ...        ...              ...             ...
# 2578   3749       2021               SE              FT
# 2579   3750       2020               SE              FT
# 2580   3751       2021               MI              FT
# 2582   3753       2020               EN              CT
# 2583   3754       2021               SE              FT
#
#                      job_title   salary salary_currency  salary_in_usd  \
# 0     Principal Data Scientist    80000             EUR          85847
# 5            Applied Scientist   222200             USD         222200
# 6            Applied Scientist   136000             USD         136000
# ...

# %% [markdown]
# ### Count and plot the job titles on the basis of experience level

# %%
df.groupby('experience_level')['job_title'].count()
# Out:
# experience_level
# EN     270
# EX      96
# MI     664
# SE    1554
# Name: job_title, dtype: int64

# %%
plt.bar(df['experience_level'],df['job_title'])
plt.show()

# %% [markdown]
# ### **Filtering data Where salary is greater than 200000**

# %%
df[df['salary']>200000]
# Out:
#       index  work_year experience_level employment_type  \
# 5         5       2023               SE              FT
# 7         7       2023               SE              FT
# 13       13       2023               EN              FT
# 21       21       2023               SE              FT
# 23       23       2023               SE              FT
# ...     ...        ...              ...             ...
# 2562   3733       2021               SE              FT
# 2563   3734       2021               MI              FT
# 2576   3747       2021               MI              FT
# 2579   3750       2020               SE              FT
# 2583   3754       2021               SE              FT
#
#                                job_title   salary salary_currency  \
# 5                      Applied Scientist   222200             USD
# 7                         Data Scientist   219000             USD
# 13                     Applied Scientist   213660             USD
# ...

# %% [markdown]
# ### **Filtering companies that are located in US**

# %%
df[df['company_location']=='US']
# Out:
#       index  work_year experience_level employment_type  \
# 1         1       2023               MI              CT
# 2         2       2023               MI              CT
# 5         5       2023               SE              FT
# 6         6       2023               SE              FT
# 9         9       2023               SE              FT
# ...     ...        ...              ...             ...
# 2578   3749       2021               SE              FT
# 2579   3750       2020               SE              FT
# 2580   3751       2021               MI              FT
# 2581   3752       2020               EN              FT
# 2582   3753       2020               EN              CT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 1                  ML Engineer   30000             USD          30000
# 2                  ML Engineer   25500             USD          25500
# 5            Applied Scientist  222200             USD         222200
# ...

# %% [markdown]
# ### **Plotting salary for every job title using scatter plot**

# %%
plt.scatter(df['salary_in_usd'],df['job_title'])
plt.show()

# %% [markdown]
# ### **Plotting count of experience level using histogram**

# %%
df.groupby('employment_type')["job_title"].count()
# Out:
# employment_type
# CT      10
# FL      10
# FT    2547
# PT      17
# Name: job_title, dtype: int64

# %%
plt.hist(df['experience_level'],bins=4)
plt.show()
